# %%
# !pip install gradio transformers torch pillow
import gradio as gr
from transformers import TrOCRProcessor, VisionEncoderDecoderModel
from PIL import Image
import torch

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
model_path = '/content/drive/MyDrive/SI26-urdu-ocr-model'

# %%
import os
os.path.exists('/content/drive/MyDrive/SI26-urdu-ocr-model')
# Out:
# True

# %%
processor = TrOCRProcessor.from_pretrained(model_path)
model = VisionEncoderDecoderModel.from_pretrained(model_path)
model.eval()
# Out:
# Loading weights:   0%|          | 0/644 [00:00<?, ?it/s]
# VisionEncoderDecoderModel(
#   (encoder): ViTModel(
#     (embeddings): ViTEmbeddings(
#       (patch_embeddings): ViTPatchEmbeddings(
#         (projection): Conv2d(3, 1024, kernel_size=(16, 16), stride=(16, 16))
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#     )
#     (layers): ModuleList(
#       (0-23): 24 x ViTLayer(
#         (attention): ViTAttention(
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=False)
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=False)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=False)
#           (o_proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
#         (layernorm_before): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#         (layernorm_after): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#         (mlp): ViTMLP(
# ...

# %%
def extract_urdu_text(image):
    """Takes an image, returns extracted Urdu text."""
    if image is None:
        return 'Please upload an image'

    pixel_values = processor(image, return_tensors='pt').pixel_values

    with torch.no_grad():
        generated_ids = model.generate(pixel_values)

    text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]
    return text if text else 'Could not extract text from this image'

# %%
interface = gr.Interface(
    fn=extract_urdu_text,
    inputs=gr.Image(type='pil', label='Upload Urdu Image'),
    outputs=gr.Textbox(label='Extracted Urdu Text'),
    title='Urdu OCR — Code Saviours SI-26',
    description='Upload an image containing Urdu text and get the extracted text.',
    examples=[]
)
interface.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://f699346a4f4a638916.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://f699346a4f4a638916.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import subprocess
result = subprocess.run(['du', '-sh', '/content/drive/MyDrive/SI26-urdu-ocr-model'], capture_output=True, text=True)
print(result.stdout)
# Out:
# 1.8G	/content/drive/MyDrive/SI26-urdu-ocr-model

# %%
# !pip install huggingface_hub
from huggingface_hub import notebook_login
notebook_login()
# Out:
# ...
# <center><img src="https://huggingface.co/front/assets/huggingface_logo-noborder.svg" width="100" alt="Hugging Face"><br><br><p>To log in, open this URL and enter the code:</p><p><a href="https://hf.co/oauth/device" target="_blank"><b>https://hf.co/oauth/device</b></a></p><p style="font-size: 1.6em; letter-spacing: 0.3em; font-family: monospace;"><b>AGBV-4PL2</b></p></center>
# <center><i>Waiting for authorization...</i></center>
# <center>Login successful. Logged in as <b>Fatimasajid</b> (token: <code>oauth-Fatimasajid</code>).<br>This token will be refreshed automatically when it expires.</center>

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
from huggingface_hub import whoami
print(whoami())
# Out:
# {'type': 'user', 'id': '6a45f371cddf91853b6aebbd', 'name': 'Fatimasajid', 'fullname': 'fatima sajid', 'canPay': False, 'billingMode': 'prepaid', 'periodEnd': 1785542400, 'isPro': False, 'avatarUrl': '/avatars/70c6f64c3858681672641a8e42cd514c.svg', 'orgs': [], 'auth': {'type': 'oauth', 'expiresAt': '2026-08-30T09:17:25.000Z'}}

# %%
from huggingface_hub import whoami
print(whoami())
# Out:
# {'type': 'user', 'id': '6a45f371cddf91853b6aebbd', 'name': 'Fatimasajid', 'fullname': 'fatima sajid', 'email': 'fatimasajid631@gmail.com', 'emailVerified': True, 'canPay': False, 'billingMode': 'prepaid', 'periodEnd': 1785542400, 'isPro': False, 'avatarUrl': '/avatars/70c6f64c3858681672641a8e42cd514c.svg', 'orgs': [], 'auth': {'type': 'access_token', 'accessToken': {'displayName': 'colab-writeee', 'role': 'write', 'createdAt': '2026-07-31T09:26:29.175Z'}}}

# %%
import shutil
shutil.make_archive('/content/urdu_model', 'zip', '/content/drive/MyDrive/SI26-urdu-ocr-model')
# Out:
# '/content/urdu_model.zip'

# %%
shutil.copy('/content/urdu_model.zip', '/content/drive/MyDrive/urdu_model.zip')
# Out:
# '/content/drive/MyDrive/urdu_model.zip'
